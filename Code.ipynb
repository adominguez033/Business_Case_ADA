# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

import pylab as plt
import seaborn as sns

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

## Libraries import

# %% [markdown]
# # Tab 1: Customer orders

# %%
df=pd.read_excel(r'C:\Users\alexd\Business_Case_ADA\Data\Customer_orders_orig.xlsx')

df.head()

## Data import
# Out:
#    PRODUCT ID  EXTERNAL ID                          NAME  \
# 0  15301699.0       4687.0  RON CACIQUE AÑEJO 70CL 37.5º
# 1  18092599.0       3474.0     BARRITA CHOCO KRISPIES 6U
# 2  15301814.0       2028.0               DONUTS GLACE 2U
# 3  18092599.0       3474.0     BARRITA CHOCO KRISPIES 6U
# 4  18092614.0       3496.0       CEREAL CORN FLAKES 500G
#
#                 COLLECTION GROUP        COLLECTION NAME COLLECTION SECTION  \
# 0                        Bebidas      Alcohol y Licores     Top Ventas,Ron
# 1  Desayunos, Panadería y Dulces               Cereales            Barrita
# 2  Desayunos, Panadería y Dulces  Pastelería y Bollería           Bollería
# 3  Desayunos, Panadería y Dulces               Cereales            Barrita
# 4  Desayunos, Panadería y Dulces               Cereales     Para Desayunar
#
#    PRODUCT PRICE  QUANTITY    ORDER ID CREATION LOCAL TIME
# 0          11.89       1.0  23899437.0 2018-12-28 02:17:44
# 1           2.39       1.0  23892594.0 2018-12-28 01:01:09
# 2           1.29       2.0  23901162.0 2018-12-28 02:40:11
# 3           2.39       1.0  23907173.0 2018-12-28 06:00:56
# 4           1.99       1.0  23900413.0 2018-12-28 02:29:43

# %%
df.info()

## Data info for Step 1: identify null values and data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67406 entries, 0 to 67405
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PRODUCT ID           67360 non-null  float64
#  1   EXTERNAL ID          67360 non-null  float64
#  2   NAME                 67360 non-null  object
#  3   COLLECTION GROUP     67345 non-null  object
#  4   COLLECTION NAME      67360 non-null  object
#  5   COLLECTION SECTION   67360 non-null  object
#  6   PRODUCT PRICE        67360 non-null  float64
#  7   QUANTITY             67360 non-null  float64
#  8   ORDER ID             67360 non-null  float64
#  9   CREATION LOCAL TIME  67406 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 5.1+ MB

# %% [markdown]
# ### Step 1: Null values + Data types per column

# %%
nan_cols=df.isnull().sum()
nan_cols[nan_cols>0]
# Out:
# PRODUCT ID            46
# EXTERNAL ID           46
# NAME                  46
# COLLECTION GROUP      61
# COLLECTION NAME       46
# COLLECTION SECTION    46
# PRODUCT PRICE         46
# QUANTITY              46
# ORDER ID              46
# dtype: int64

# %%
qty_of_nuls = 8
df.iloc[df[(df.isnull().sum(axis=1)>qty_of_nuls)].index]
# Out:
#      PRODUCT ID  EXTERNAL ID NAME COLLECTION GROUP COLLECTION NAME  \
# 65          NaN          NaN  NaN              NaN             NaN
# 68          NaN          NaN  NaN              NaN             NaN
# 71          NaN          NaN  NaN              NaN             NaN
# 74          NaN          NaN  NaN              NaN             NaN
# 77          NaN          NaN  NaN              NaN             NaN
# 80          NaN          NaN  NaN              NaN             NaN
# 83          NaN          NaN  NaN              NaN             NaN
# 86          NaN          NaN  NaN              NaN             NaN
# 89          NaN          NaN  NaN              NaN             NaN
# 92          NaN          NaN  NaN              NaN             NaN
# 95          NaN          NaN  NaN              NaN             NaN
# 98          NaN          NaN  NaN              NaN             NaN
# 101         NaN          NaN  NaN              NaN             NaN
# 104         NaN          NaN  NaN              NaN             NaN
# 107         NaN          NaN  NaN              NaN             NaN
# 110         NaN          NaN  NaN              NaN             NaN
# 113         NaN          NaN  NaN              NaN             NaN
# 116         NaN          NaN  NaN              NaN             NaN
# 119         NaN          NaN  NaN              NaN             NaN
# 122         NaN          NaN  NaN              NaN             NaN
# 125         NaN          NaN  NaN              NaN             NaN
# 128         NaN          NaN  NaN              NaN             NaN
# 131         NaN          NaN  NaN              NaN             NaN
# 134         NaN          NaN  NaN              NaN             NaN
# 137         NaN          NaN  NaN              NaN             NaN
# 139         NaN          NaN  NaN              NaN             NaN
# 141         NaN          NaN  NaN              NaN             NaN
# 143         NaN          NaN  NaN              NaN             NaN
# 145         NaN          NaN  NaN              NaN             NaN
# 147         NaN          NaN  NaN              NaN             NaN
# 149         NaN          NaN  NaN              NaN             NaN
# 151         NaN          NaN  NaN              NaN             NaN
# 153         NaN          NaN  NaN              NaN             NaN
# 155         NaN          NaN  NaN              NaN             NaN
# 157         NaN          NaN  NaN              NaN             NaN
# 159         NaN          NaN  NaN              NaN             NaN
# 161         NaN          NaN  NaN              NaN             NaN
# 163         NaN          NaN  NaN              NaN             NaN
# 165         NaN          NaN  NaN              NaN             NaN
# 167         NaN          NaN  NaN              NaN             NaN
# 169         NaN          NaN  NaN              NaN             NaN
# 171         NaN          NaN  NaN              NaN             NaN
# 173         NaN          NaN  NaN              NaN             NaN
# 175         NaN          NaN  NaN              NaN             NaN
# 177         NaN          NaN  NaN              NaN             NaN
# 179         NaN          NaN  NaN              NaN             NaN
#
#     COLLECTION SECTION  PRODUCT PRICE  QUANTITY  ORDER ID CREATION LOCAL TIME
# 65                 NaN            NaN       NaN       NaN 2018-12-28 11:59:09
# 68                 NaN            NaN       NaN       NaN 2018-12-28 10:54:12
# 71                 NaN            NaN       NaN       NaN 2018-12-28 10:05:31
# 74                 NaN            NaN       NaN       NaN 2018-12-28 10:50:22
# 77                 NaN            NaN       NaN       NaN 2018-12-28 09:36:57
# 80                 NaN            NaN       NaN       NaN 2018-12-28 09:35:44
# 83                 NaN            NaN       NaN       NaN 2018-12-28 13:38:11
# 86                 NaN            NaN       NaN       NaN 2018-12-28 14:24:06
# 89                 NaN            NaN       NaN       NaN 2018-12-28 09:51:03
# 92                 NaN            NaN       NaN       NaN 2018-12-28 10:27:40
# 95                 NaN            NaN       NaN       NaN 2018-12-28 11:09:27
# 98                 NaN            NaN       NaN       NaN 2018-12-28 13:45:00
# 101                NaN            NaN       NaN       NaN 2018-12-28 10:29:33
# 104                NaN            NaN       NaN       NaN 2018-12-28 09:04:54
# 107                NaN            NaN       NaN       NaN 2018-12-28 12:15:29
# 110                NaN            NaN       NaN       NaN 2018-12-28 11:36:49
# 113                NaN            NaN       NaN       NaN 2018-12-28 07:38:03
# 116                NaN            NaN       NaN       NaN 2018-12-28 09:24:03
# 119                NaN            NaN       NaN       NaN 2018-12-28 11:41:48
# 122                NaN            NaN       NaN       NaN 2018-12-28 10:02:00
# 125                NaN            NaN       NaN       NaN 2018-12-28 14:08:58
# 128                NaN            NaN       NaN       NaN 2018-12-28 12:17:33
# 131                NaN            NaN       NaN       NaN 2018-12-28 11:30:59
# 134                NaN            NaN       NaN       NaN 2018-12-28 12:41:48
# 137                NaN            NaN       NaN       NaN 2018-12-28 09:03:54
# 139                NaN            NaN       NaN       NaN 2018-12-28 11:48:45
# 141                NaN            NaN       NaN       NaN 2018-12-28 14:53:26
# 143                NaN            NaN       NaN       NaN 2018-12-28 14:12:06
# 145                NaN            NaN       NaN       NaN 2018-12-28 09:29:36
# 147                NaN            NaN       NaN       NaN 2018-12-28 13:20:01
# 149                NaN            NaN       NaN       NaN 2018-12-28 14:08:36
# 151                NaN            NaN       NaN       NaN 2018-12-28 06:46:46
# 153                NaN            NaN       NaN       NaN 2018-12-28 11:33:28
# 155                NaN            NaN       NaN       NaN 2018-12-28 11:47:45
# 157                NaN            NaN       NaN       NaN 2018-12-28 11:21:37
# 159                NaN            NaN       NaN       NaN 2018-12-28 12:58:09
# 161                NaN            NaN       NaN       NaN 2018-12-28 07:33:03
# 163                NaN            NaN       NaN       NaN 2018-12-28 10:53:29
# 165                NaN            NaN       NaN       NaN 2018-12-28 08:00:56
# 167                NaN            NaN       NaN       NaN 2018-12-28 10:05:08
# 169                NaN            NaN       NaN       NaN 2018-12-28 12:00:16
# 171                NaN            NaN       NaN       NaN 2018-12-28 09:55:02
# 173                NaN            NaN       NaN       NaN 2018-12-28 10:43:30
# 175                NaN            NaN       NaN       NaN 2018-12-28 14:07:07
# 177                NaN            NaN       NaN       NaN 2018-12-28 11:04:55
# 179                NaN            NaN       NaN       NaN 2018-12-28 14:12:52

# %%
df = df.drop(df[df.isnull().sum(axis=1) > 8].index)

## Drop of rows with Null values.

# %%
df.columns =['product_id', 'external_id', 'name', 'collection_group', 'collection_name', 'collection_section', 'product_price', 'quantity', 'order_id', 'date']

## Columns names are changed in order to call them easily.

# %%
df.fillna({'collection_group': 'Sin clasificar'}, inplace=True)

## Still null values, but relevant information in other columns. So let's treat the collection group as "sin clasificar"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67360 entries, 0 to 67405
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          67360 non-null  float64
#  1   external_id         67360 non-null  float64
#  2   name                67360 non-null  object
#  3   collection_group    67360 non-null  object
#  4   collection_name     67360 non-null  object
#  5   collection_section  67360 non-null  object
#  6   product_price       67360 non-null  float64
#  7   quantity            67360 non-null  float64
#  8   order_id            67360 non-null  float64
#  9   date                67360 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 5.7+ MB

# %%
df['product_id'] = df['product_id'].astype('int')
df['external_id'] = df['external_id'].astype('int')
df['quantity'] = df['quantity'].astype('int')
df['order_id'] = df['order_id'].astype('int')

## Some columns are integer values, so data type is changed.

# %%
df.collection_group.unique()
# Out:
# array(['Bebidas', 'Desayunos, Panadería y Dulces', 'Alimentación General',
#        'Lácteos y Quesos', 'Frescos, Charcutería y Huevos',
#        'Higiene, Belleza y Bebés', 'Pizzas y Congelados,Navidad',
#        'Desayunos, Panadería y Dulces,Navidad', 'Pizzas y Congelados',
#        'Bebidas,Hogar y limpieza', 'Bebidas,Pizzas y Congelados',
#        'Bebidas,Navidad', 'Navidad,Pizzas y Congelados',
#        'Frescos, Charcutería y Huevos,Navidad', 'Hogar y limpieza',
#        'Navidad', 'Alimentación General,Navidad',
#        'Higiene, Belleza y Bebés,Navidad',
#        'Navidad,Frescos, Charcutería y Huevos', 'Sin clasificar'],
#       dtype=object)

# %%
campaña_navidad = {'General,Navidad','Bebidas,Navidad','Dulces,Navidad','Huevos,Navidad','Bebés,Navidad','Congelados,Navidad','Navidad','Navidad,Frescos,','Navidad,Pizzas'}

df['navidad'] = df['collection_group'].apply(lambda x: sum(i in campaña_navidad for i in x.split()))

## Column creation for "Navidad" products

# %%
df.collection_group.replace(['Bebidas', 'Desayunos, Panadería y Dulces', 'Alimentación General',
       'Lácteos y Quesos', 'Frescos, Charcutería y Huevos',
       'Higiene, Belleza y Bebés', 'Pizzas y Congelados,Navidad',
       'Desayunos, Panadería y Dulces,Navidad', 'Pizzas y Congelados',
       'Bebidas,Hogar y limpieza', 'Bebidas,Pizzas y Congelados',
       'Bebidas,Navidad', 'Navidad,Pizzas y Congelados',
       'Frescos, Charcutería y Huevos,Navidad', 'Hogar y limpieza',
       'Navidad', 'Alimentación General,Navidad',
       'Higiene, Belleza y Bebés,Navidad',
       'Navidad,Frescos, Charcutería y Huevos', 'Sin clasificar'],
                            ['Bebidas', 'Desayunos, Panadería y Dulces', 'Alimentación General',
       'Lácteos y Quesos', 'Frescos, Charcutería y Huevos',
       'Higiene, Belleza y Bebés', 'Pizzas y Congelados',
       'Desayunos, Panadería y Dulces', 'Pizzas y Congelados',
       'Bebidas,Hogar y limpieza', 'Bebidas,Pizzas y Congelados',
       'Bebidas', 'Pizzas y Congelados',
       'Frescos, Charcutería y Huevos', 'Hogar y limpieza',
       'Navidad', 'Alimentación General',
       'Higiene, Belleza y Bebés',
       'Frescos, Charcutería y Huevos', 'Sin clasificar'],regex=True,inplace=True)

## Rows containing "Navidad" is eliminated, since another column is created.

# %%
df.collection_name.unique()
# Out:
# array(['Alcohol y Licores', 'Cereales', 'Pastelería y Bollería',
#        'Pasta, Arroz y Sopas', 'Galletas', 'Chocolates', 'Refrescos',
#        'Cerveza', 'Agua', 'Aperitivos Salados', 'Vinos',
#        'Platos Preparados y Noodles', 'Leche', 'Salsas', 'Charcutería',
#        'Zumos', 'Higiene Bucal', 'Parafarmacia', 'Cuidado Corporal',
#        'Dietéticos', 'Yogures Y Fermentados', 'Cuidado Capilar',
#        'Patés y untables', 'Conservas', 'Helados,Congelado', 'Untables',
#        'Café, Cacao e Infusiones', 'Panadería', 'Galletas,Dulces',
#        'Helados', 'Quesos',
#        'Alcohol y Licores,Platos y Vasos de Plástico',
#        'Pastelería y Bollería,Dulces', 'Alcohol y Licores,Hielo',
#        'Alcohol y Licores,Selección Whisky', 'Pizzas', 'Higiene Íntima',
#        'Congelado,Helados', 'Caramelos y Golosinas', 'Frutas y Verduras',
#        'Charcutería,Embutidos y Charcutería', 'Platos Preparados',
#        'Lavadora', 'Congelado', 'Pescado', 'Celulosa', 'Lavavajillas',
#        'Huevos', 'Bebés Alimentación', 'Sal, Azúcar y Especias',
#        'Cuidado de Bebés', 'Aceite y Vinagre', 'Chocolates,Dulces',
#        'Champagnes y Espumosos', 'Bolsas de basura',
#        'Chocolates,Nestlé Caja Roja', 'Nata', 'Limpieza', 'Legumbres',
#        'Harinas y Levaduras', 'Conservación de alimentos',
#        'Verdura Congelada', 'Conservas,Uva', 'Embutidos y Charcutería',
#        'Platos y Vasos de Plástico', 'Packs para el cuerpo',
#        'Champagnes y Espumosos,Champagne y Cava',
#        'Cuidado Corporal,Packs para el cuerpo',
#        'Embutidos y Charcutería,Charcutería',
#        'Especial Navidad,Charcutería', 'Cuidado Corporal,Perfumería',
#        'Charcutería,Especial Navidad', 'Galletas,Especial Navidad',
#        'Chocolates,Especial Navidad',
#        'Pastelería y Bollería,Especial Navidad',
#        'Sin clasificar,Pastelería y Bollería',
#        'Sin clasificar,Chocolates', 'Charcutería,Sin clasificar',
#        'Sin clasificar,Charcutería', 'Sin clasificar',
#        'Sin clasificar,Galletas', 'Celulosa Y Bolsas de Basura'],
#       dtype=object)

# %%
df.collection_section.unique()
# Out:
# array(['Top Ventas,Ron', 'Barrita', 'Bollería', 'Para Desayunar', 'Pasta',
#        'Chocolate', 'Tableta', 'Otras', 'Pastelitos', 'Pack y Litro',
#        'Sin Gas', 'Desayuno', 'Encurtidos', 'Blanco', 'En Conserva',
#        'Tonica', 'Semidesnatada', 'Mayonesa', 'Energetica', 'Salchichas',
#        'zumos', 'Dentífrico', 'Primeros Auxilios', 'Gel y Jabon', 'Cola',
#        'Whisky,Top Ventas', 'Ron', 'Snack', 'Top Ventas,Vodka',
#        'Palomitas', 'Deportivo', 'Patatas Fritas', 'Tortita', 'Naranja',
#        'Tinto', 'Tea', 'Bebido', 'Champú', 'Limon', 'Queso', 'Lata',
#        'Fuet y Salchichón', 'Mejillon', 'Tarrinas,Helados y Tartas',
#        'Whisky', 'Ginebra', 'Jamon', 'Cacao', 'Café',
#        'Pan Burguer/Hot Dog', 'Aceitunas', 'Laca y Otros',
#        'Otras,Galletas surtidas', 'Top Ventas,Licor y Crema',
#        'De Palo y Conos', 'Snacks', 'Pan de Molde', 'MANCHEGO', 'Pavo',
#        'Top Ventas,Vasos', 'Turrones y Polvorones', 'Top Ventas,Hielo',
#        'Entera', 'Congeladas', 'Rosado', 'Botellin', 'BOLA / EDAM',
#        'Pastelitos,Bollería', 'Noodles', 'Sin Lactosa', 'Compresa',
#        'Helados y Tartas,Tarta Helada', 'Caramelos', 'Verduras',
#        'Gominolas', 'Desodorante', 'Atun', 'Afeitado', 'Nachos', 'Bebida',
#        'Jamon York,Charcutería', 'Jamon York', 'Arroz', 'Berberechos',
#        'Pate', 'Suavizantes', 'Marisco',
#        'Bifidus, Desnatados y Especiales', 'Pescado', 'Papel Higiénico',
#        'Lavavajillas', 'Detergentes', 'Con Gas', 'Pan Tostado',
#        'Papel Cocina', 'Conservas vegetales', 'Huevos', 'Sopa', 'Postres',
#        'Sabores', 'Tomate', 'Fajitas', 'Leches', 'Desnatada', 'Azúcar',
#        'Pañales', 'Tarrinas', 'Frutos Secos y Pipas', 'Aceite',
#        'Mermelada', 'Bombón,Bombones y chocolates',
#        'RESTO QUESOS LECHE D', 'Papillas', 'Champagne', 'Tampón',
#        'Bolsas de Basura', 'Vodka', 'Gulas', 'Bombón,Caja Roja', 'Cava',
#        'Lomo', 'Margarina', 'NATA', 'Frutas', 'Sidra',
#        'Bifidus, Desnatados y Especiales,Bifidus, Desnatados y Especiales, Desnatados y Especiales',
#        'Limpiadores', 'Crema', 'Mantequilla', 'Garbanzo', 'Levadura',
#        'Film Aluminio/Transparente', 'GOUDA', 'Harina', 'Chorizo',
#        'Caldo', 'Desengrasante', 'Bacon', 'Picantes', 'Guacamole',
#        'Potitos', 'Dulce de Leche', 'Lejía', 'Lasaña',
#        'Verdura Congelada', 'Preservativos', 'Chicle', 'Sal', 'Pollo',
#        'Griego', 'Bombón', 'Elixires', 'Multiusos',
#        'Utensilios de limpieza', 'San Jacobo', 'Ketchup', 'Más Salsas',
#        'Conserva de Fruta', 'Galletas', 'Infantiles', 'Mortadela',
#        'Conserva de Fruta,Uva', 'Sin Alcohol', 'Pañuelos', 'Jabón',
#        'Hidratantes', 'Pan', 'Anchoa', 'Charcutería', 'Infusiones',
#        'Canelon', 'Lenteja', 'Vinagre y Balsámico', 'Edulcorante',
#        'Salvaslip', 'Helados y Tartas', 'Licor y Crema', 'Acondicionador',
#        'Top Ventas,Ginebra', 'Chorizo,Fuet y Salchichón,Charcutería',
#        'Cepillos y Sedas', 'Cuidado de la piel', 'Platos',
#        'Packs para cuerpo', 'Mostaza', 'Especias',
#        'Champagne,Champange y Cava', 'Bonito', 'Brandy', 'Sardina',
#        'Quinoa', 'Miel', 'Cava,Champange y Cava', 'Vasos',
#        'Desodorante,Packs para cuerpo', 'Charcutería,Jamon York',
#        'Jamon,Charcutería', 'Charcutería,Chorizo,Fuet y Salchichón',
#        'Alubia', 'Fuet', 'Desodorante,Hombre', 'Top Ventas,Whisky',
#        'Sin clasificar,Turrones y Polvorones', 'Sin clasificar,Bombón',
#        'Jamon,Sin clasificar', 'Sin clasificar,Jamon York',
#        'Sin clasificar', 'Especial', 'Sin clasificar,Otras',
#        'Sin clasificar,Chorizo,Fuet y Salchichón', 'Sobrasada',
#        'Vodka,Top Ventas', 'Ginebra,Top Ventas', 'Hielo', 'Zumos'],
#       dtype=object)

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['day'] = pd.DatetimeIndex(df['date']).day
df['time'] = pd.DatetimeIndex(df['date']).time

## Time split per year, month, day and time.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67360 entries, 0 to 67405
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          67360 non-null  int32
#  1   external_id         67360 non-null  int32
#  2   name                67360 non-null  object
#  3   collection_group    67360 non-null  object
#  4   collection_name     67360 non-null  object
#  5   collection_section  67360 non-null  object
#  6   product_price       67360 non-null  float64
#  7   quantity            67360 non-null  int32
#  8   order_id            67360 non-null  int32
#  9   date                67360 non-null  datetime64[ns]
#  10  navidad             67360 non-null  int64
#  11  year                67360 non-null  int64
#  12  month               67360 non-null  int64
#  13  day                 67360 non-null  int64
#  14  time                67360 non-null  object
# dtypes: datetime64[ns](1), float64(1), int32(4), int64(4), object(5)
# memory usage: 7.2+ MB

# %%
df.head()
# Out:
#    product_id  external_id                          name  \
# 0    15301699         4687  RON CACIQUE AÑEJO 70CL 37.5º
# 1    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 2    15301814         2028               DONUTS GLACE 2U
# 3    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 4    18092614         3496       CEREAL CORN FLAKES 500G
#
#                 collection_group        collection_name collection_section  \
# 0                        Bebidas      Alcohol y Licores     Top Ventas,Ron
# 1  Desayunos, Panadería y Dulces               Cereales            Barrita
# 2  Desayunos, Panadería y Dulces  Pastelería y Bollería           Bollería
# 3  Desayunos, Panadería y Dulces               Cereales            Barrita
# 4  Desayunos, Panadería y Dulces               Cereales     Para Desayunar
#
#    product_price  quantity  order_id                date  navidad  year  \
# 0          11.89         1  23899437 2018-12-28 02:17:44        0  2018
# 1           2.39         1  23892594 2018-12-28 01:01:09        0  2018
# 2           1.29         2  23901162 2018-12-28 02:40:11        0  2018
# 3           2.39         1  23907173 2018-12-28 06:00:56        0  2018
# 4           1.99         1  23900413 2018-12-28 02:29:43        0  2018
#
#    month  day      time
# 0     12   28  02:17:44
# 1     12   28  01:01:09
# 2     12   28  02:40:11
# 3     12   28  06:00:56
# 4     12   28  02:29:43

# %%
df['revenue']=df['product_price']*df['quantity']

## Introduction of a new column to calculate p*q (for later being able to calculate average order size)

# %%
df.head()
# Out:
#    product_id  external_id                          name  \
# 0    15301699         4687  RON CACIQUE AÑEJO 70CL 37.5º
# 1    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 2    15301814         2028               DONUTS GLACE 2U
# 3    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 4    18092614         3496       CEREAL CORN FLAKES 500G
#
#                 collection_group        collection_name collection_section  \
# 0                        Bebidas      Alcohol y Licores     Top Ventas,Ron
# 1  Desayunos, Panadería y Dulces               Cereales            Barrita
# 2  Desayunos, Panadería y Dulces  Pastelería y Bollería           Bollería
# 3  Desayunos, Panadería y Dulces               Cereales            Barrita
# 4  Desayunos, Panadería y Dulces               Cereales     Para Desayunar
#
#    product_price  quantity  order_id                date  navidad  year  \
# 0          11.89         1  23899437 2018-12-28 02:17:44        0  2018
# 1           2.39         1  23892594 2018-12-28 01:01:09        0  2018
# 2           1.29         2  23901162 2018-12-28 02:40:11        0  2018
# 3           2.39         1  23907173 2018-12-28 06:00:56        0  2018
# 4           1.99         1  23900413 2018-12-28 02:29:43        0  2018
#
#    month  day      time  revenue
# 0     12   28  02:17:44    11.89
# 1     12   28  01:01:09     2.39
# 2     12   28  02:40:11     2.58
# 3     12   28  06:00:56     2.39
# 4     12   28  02:29:43     1.99

# %% [markdown]
# ### Step 2: KPIs determination

# %%
len(df.order_id.unique())

## Total orders.
# Out:
# 19015

# %%
df.quantity.sum()
# Out:
# 119753

# %%
sum(df.revenue)

## Total revenue (p*q)
# Out:
# 234437.65000001923

# %%
df.groupby('order_id').sum().revenue.mean()

## global average order size
# Out:
# 12.329090191953771

# %%
df.groupby('order_id').sum().quantity.mean()

## global average quantity per order
# Out:
# 6.297817512490139

# %%
df.groupby('order_id').count().external_id.mean()

## average amount of different products per order.
# Out:
# 3.542466473836445

# %%
df.product_price.mean()

## average product price.
# Out:
# 2.579789934679338

# %%
len(df.external_id.unique())

## Unique products delivered.
# Out:
# 837

# %%
print(len(df.collection_group.unique())) ; print(len(df.collection_name.unique())) ; print(len(df.collection_section.unique())) 

## Types of collection group, collection names and collection sections.
# Out:
# 12
# 82
# 215

# %%
ax=df.groupby('collection_group').order_id.nunique().plot(
        kind='pie',
        grid=True,
        figsize=(12,8),
        autopct='%1.0f%%',
        title='Number of orders per month')

plt.show();

# %%
print(df.groupby('month').sum().quantity), print(df.groupby('month').sum().revenue), print(df.groupby('month').order_id.nunique())

## Number of quantity, revenue, and orders per month.
# Out:
# month
# 10    11505.0
# 11    40064.0
# 12    68184.0
# Name: quantity, dtype: float64
# month
# 10     21297.74
# 11     77326.40
# 12    135813.51
# Name: revenue, dtype: float64
# month
# 10     1928
# 11     6562
# 12    10525
# Name: order_id, dtype: int64
# (None, None, None)

# %%
ax=df.groupby('month').order_id.nunique().plot(
        kind='pie',
        grid=True,
        figsize=(12,8),
        autopct='%1.0f%%',
        title='Number of orders per month')

plt.show();

# %%
por_tipo_oferta=df.loc[df.navidad==1]\
                        .groupby('order_id').sum().revenue.mean()

por_tipo_oferta


## PENDIENTE COMENTAR
# Out:
# 9.67388888888887

# %%
new_df = df.groupby(['order_id'], sort=True).sum().revenue.reset_index()
new_df = new_df.sort_values(by = ['revenue'], ascending=[False])
print(new_df); sns.distplot(new_df.revenue);
# Out:
#        order_id  revenue
# 11552  21611721   516.78
# 6264   19778825   369.40
# 6129   19709559   288.01
# 7979   20553465   227.56
# 12794  21969470   202.81
# ...         ...      ...
# 13063  22071582     0.61
# 14194  22451993     0.61
# 829    16772309     0.60
# 2667   17824919     0.60
# 6665   20005489     0.59
#
# [19015 rows x 2 columns]
# C:\Users\alexd\Downloads\DescargaAnaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
new_df2 = df.groupby(['name'], sort=True).sum().revenue.reset_index()
new_df2 = new_df2.sort_values(by = ['revenue'], ascending=[False])
new_df2.head(20)

## total revenue per product.
# Out:
#                                     name  revenue
# 844     WHISKY J.WALKER RED T.I.70CL 40º  5479.34
# 209      CERVEZA MAHOU 5* LATA 33CL 5.5º  4227.88
# 112           BOLSA HIELO ALIMENTARIO 2K  3897.54
# 408         GINEBRA TANQUERAY 70CL 43.1º  3835.87
# 705            RON BRUGAL AÑEJO 70CL 38º  3735.80
# 210        CERVEZA MAHOU CLASICA 1L 4.8º  3640.31
# 706         RON CACIQUE AÑEJO 70CL 37.5º  3533.42
# 704         RON BARCELO AÑEJO 70CL 37.5º  3362.42
# 212      CERVEZA MAHOU CLASICA 33CL 4.8º  3199.14
# 840      WHISKY J. WALKER BLACK 70CL 40º  2915.17
# 218    CHAMPAGNE VEUVE CLICQUOT 75CL 12º  2739.64
# 830          VODKA ABSOLUT T.I. 70CL 40º  2581.84
# 817     VINO CUNE TTO.CRIANZA 75CL 13.5º  2550.68
# 216  CHAMPAGNE MOET CHANDON IMP.75CL 12º  2404.51
# 401       GINEBRA BEEFEATER T.I.70CL 40º  2383.01
# 207       CERVEZA MAHOU 5* 25CL P-6 5.5º  2093.97
# 273                      COCACOLA PET 2L  2030.86
# 835         WHISKY BALLANTINE'S 70CL 40º  1929.78
# 276                 COCACOLA ZERO PET 2L  1911.96
# 708                 RON NEGRITA 1L 37.5º  1897.97

# %%
new_df3 = df.groupby(['order_id','collection_group'], sort=True).sum()['revenue'].reset_index()
new_df3 = new_df3.sort_values(by = ['order_id'], ascending=[True])
new_df3
# Out:
#        order_id               collection_group  revenue
# 0      15924126           Alimentación General     1.90
# 1      15930564  Desayunos, Panadería y Dulces     4.50
# 2      15930564  Frescos, Charcutería y Huevos     2.00
# 3      15933742                        Bebidas     0.84
# 4      15933742  Desayunos, Panadería y Dulces     2.05
# ...         ...                            ...      ...
# 35992  23907173               Lácteos y Quesos     4.81
# 35990  23907173                        Bebidas     8.88
# 35993  23907173            Pizzas y Congelados     3.65
# 35994  23907474                        Bebidas    15.65
# 35995  23907474    Bebidas,Pizzas y Congelados     1.20
#
# [35996 rows x 3 columns]

# %%
ax=new_df3.groupby('collection_group').sum().revenue.plot(
        kind='pie',
        grid=True,
        figsize=(12,8),
        autopct='%1.0f%%',
        title='Revenue per collection_group')

plt.show();

# %%
new_df3.revenue.sum()
# Out:
# 234437.65

# %%
new_df3.groupby('order_id').count().collection_group
# Out:
# order_id
# 15924126    1
# 15930564    2
# 15933742    3
# 15934639    2
# 15935340    1
#            ..
# 23906486    1
# 23906620    1
# 23907073    1
# 23907173    4
# 23907474    2
# Name: collection_group, Length: 19015, dtype: int64

# %%
new_df3.groupby('order_id').count().collection_group.mean()
# Out:
# 1.8930318169865896

# %%
aos=[]
for e in new_df3.collection_group.unique():
    result=new_df3.loc[new_df3.collection_group==e]\
                    .groupby('order_id')\
                    .sum().revenue.mean()
    aos.append(result)

# %%
aos_title=np.array(new_df3.collection_group.unique()).tolist()

aos_by_collection_group = pd.DataFrame({'collection_group' :aos_title ,
                                        'aos' :aos})
aos_by_collection_group


# average order size by collection_group
# Out:
#                  collection_group        aos
# 0            Alimentación General   4.822448
# 1   Desayunos, Panadería y Dulces   5.190475
# 2   Frescos, Charcutería y Huevos   3.929163
# 3                         Bebidas  10.193234
# 4                Lácteos y Quesos   3.102598
# 5                Hogar y limpieza   6.873153
# 6        Higiene, Belleza y Bebés   6.483470
# 7                  Sin clasificar   6.578333
# 8             Pizzas y Congelados   5.548225
# 9     Bebidas,Pizzas y Congelados   2.040396
# 10       Bebidas,Hogar y limpieza   1.415644
# 11                        Navidad   6.078824

# %%
df.head()
# Out:
#    product_id  external_id                          name  \
# 0    15301699         4687  RON CACIQUE AÑEJO 70CL 37.5º
# 1    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 2    15301814         2028               DONUTS GLACE 2U
# 3    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 4    18092614         3496       CEREAL CORN FLAKES 500G
#
#                 collection_group        collection_name collection_section  \
# 0                        Bebidas      Alcohol y Licores     Top Ventas,Ron
# 1  Desayunos, Panadería y Dulces               Cereales            Barrita
# 2  Desayunos, Panadería y Dulces  Pastelería y Bollería           Bollería
# 3  Desayunos, Panadería y Dulces               Cereales            Barrita
# 4  Desayunos, Panadería y Dulces               Cereales     Para Desayunar
#
#    product_price  quantity  order_id                date  navidad  year  \
# 0          11.89         1  23899437 2018-12-28 02:17:44        0  2018
# 1           2.39         1  23892594 2018-12-28 01:01:09        0  2018
# 2           1.29         2  23901162 2018-12-28 02:40:11        0  2018
# 3           2.39         1  23907173 2018-12-28 06:00:56        0  2018
# 4           1.99         1  23900413 2018-12-28 02:29:43        0  2018
#
#    month  day      time  revenue
# 0     12   28  02:17:44    11.89
# 1     12   28  01:01:09     2.39
# 2     12   28  02:40:11     2.58
# 3     12   28  06:00:56     2.39
# 4     12   28  02:29:43     1.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67360 entries, 0 to 67405
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          67360 non-null  int32
#  1   external_id         67360 non-null  int32
#  2   name                67360 non-null  object
#  3   collection_group    67360 non-null  object
#  4   collection_name     67360 non-null  object
#  5   collection_section  67360 non-null  object
#  6   product_price       67360 non-null  float64
#  7   quantity            67360 non-null  int32
#  8   order_id            67360 non-null  int32
#  9   date                67360 non-null  datetime64[ns]
#  10  navidad             67360 non-null  int64
#  11  year                67360 non-null  int64
#  12  month               67360 non-null  int64
#  13  day                 67360 non-null  int64
#  14  time                67360 non-null  object
#  15  revenue             67360 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(4), int64(4), object(5)
# memory usage: 7.7+ MB

# %%
df['time'] = df['time'].astype('str')

# %%
import warnings
warnings.simplefilter('ignore')

# %%
df.time[df.time.str.startswith('00')]='Madrugada'
df.time[df.time.str.startswith('01')]='Madrugada'
df.time[df.time.str.startswith('02')]='Madrugada'
df.time[df.time.str.startswith('03')]='Madrugada'
df.time[df.time.str.startswith('04')]='Madrugada'
df.time[df.time.str.startswith('05')]='Madrugada'
df.time[df.time.str.startswith('06')]='Mañana'
df.time[df.time.str.startswith('07')]='Mañana'
df.time[df.time.str.startswith('08')]='Mañana'
df.time[df.time.str.startswith('09')]='Mañana'
df.time[df.time.str.startswith('10')]='Mañana'
df.time[df.time.str.startswith('11')]='Mañana'
df.time[df.time.str.startswith('12')]='Tarde'
df.time[df.time.str.startswith('13')]='Tarde'
df.time[df.time.str.startswith('14')]='Tarde'
df.time[df.time.str.startswith('15')]='Tarde'
df.time[df.time.str.startswith('16')]='Tarde'
df.time[df.time.str.startswith('17')]='Tarde'
df.time[df.time.str.startswith('18')]='Noche'
df.time[df.time.str.startswith('19')]='Noche'
df.time[df.time.str.startswith('20')]='Noche'
df.time[df.time.str.startswith('21')]='Noche'
df.time[df.time.str.startswith('22')]='Noche'
df.time[df.time.str.startswith('23')]='Noche'

# %%
aos2=[]
for e in df.time.unique():
    result=df.loc[df.time==e]\
                    .groupby('order_id')\
                    .sum().revenue.mean()
    aos2.append(result)

# %%
aos2_title=np.array(df.time.unique()).tolist()

aos2_by_collection_group = pd.DataFrame({'time_day' :aos2_title ,
                                        'aos' :aos2})
aos2_by_collection_group


# average order size by collection_group
# Out:
#     time_day        aos
# 0  Madrugada  11.635369
# 1     Mañana  12.224196
# 2      Tarde  13.277844
# 3      Noche  12.174597

# %%
ax=df.groupby('time').sum().revenue.plot(
        kind='pie',
        grid=True,
        figsize=(12,8),
        autopct='%1.0f%%',
        title='Revenue per time of the day')

plt.show();

# %% [markdown]
# ### Step 3:

# %%
por_tipo_oferta=df.loc[df.response=='Yes']\
                    .groupby('renew_offer_type')\
                    .count().customer/data.groupby('renew_offer_type').count().customer

por_tipo_oferta
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1056/3877599928.py in <module>
# ----> 1 por_tipo_oferta=df.loc[df.response=='Yes']\
#       2                     .groupby('renew_offer_type')\
#       3                     .count().customer/data.groupby('renew_offer_type').count().customer
#       4
#       5 por_tipo_oferta
#
# ~\Downloads\DescargaAnaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'response'

# %%
ax=df.groupby('order_id').count().collection_group.plot(
        kind='pie',
        grid=True,
        figsize=(12,8),
        title='Engagement')


plt.show();

# %%
df.revenue.mean()

# %%
df.groupby('order_id').sum().revenue.mean()

# global average order size

# %%
aos=[]
for e in df.collection_group.unique():
    result=df.loc[df.collection_group==e]\
                    .groupby('order_id')\
                    .sum().revenue.mean()
    aos.append(result)
    

av_q=[]
for e in df.collection_group.unique():
    result2=df.loc[df.collection_group==e]\
                    .groupby('order_id')\
                    .sum().quantity.mean()
    av_q.append(result2)
    

av_p=[]
for e in df.collection_group.unique():
    result3=df.loc[df.collection_group==e]\
                    .groupby('order_id')\
                    .sum().product_price.mean()
    av_p.append(result3)


    
aos_title=np.array(df.collection_group.unique()).tolist()

aos_by_collection_group = pd.DataFrame({'collection_group' :aos_title ,
                                        'aos' :aos,
                                        'av_q' :av_q,
                                        'av_p' :av_p})
aos_by_collection_group


# average order size by collection_group

# %%
df.head()
# Out:
#    product_id  external_id                          name  \
# 0    15301699         4687  RON CACIQUE AÑEJO 70CL 37.5º
# 1    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 2    15301814         2028               DONUTS GLACE 2U
# 3    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 4    18092614         3496       CEREAL CORN FLAKES 500G
#
#                 collection_group        collection_name collection_section  \
# 0                        Bebidas      Alcohol y Licores     Top Ventas,Ron
# 1  Desayunos, Panadería y Dulces               Cereales            Barrita
# 2  Desayunos, Panadería y Dulces  Pastelería y Bollería           Bollería
# 3  Desayunos, Panadería y Dulces               Cereales            Barrita
# 4  Desayunos, Panadería y Dulces               Cereales     Para Desayunar
#
#    product_price  quantity  order_id                date  navidad  year  \
# 0          11.89         1  23899437 2018-12-28 02:17:44        0  2018
# 1           2.39         1  23892594 2018-12-28 01:01:09        0  2018
# 2           1.29         2  23901162 2018-12-28 02:40:11        0  2018
# 3           2.39         1  23907173 2018-12-28 06:00:56        0  2018
# 4           1.99         1  23900413 2018-12-28 02:29:43        0  2018
#
#    month  day       time  revenue
# 0     12   28  Madrugada    11.89
# 1     12   28  Madrugada     2.39
# 2     12   28  Madrugada     2.58
# 3     12   28     Mañana     2.39
# 4     12   28  Madrugada     1.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67360 entries, 0 to 67405
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          67360 non-null  int32
#  1   external_id         67360 non-null  int32
#  2   name                67360 non-null  object
#  3   collection_group    67360 non-null  object
#  4   collection_name     67360 non-null  object
#  5   collection_section  67360 non-null  object
#  6   product_price       67360 non-null  float64
#  7   quantity            67360 non-null  int32
#  8   order_id            67360 non-null  int32
#  9   date                67360 non-null  datetime64[ns]
#  10  navidad             67360 non-null  int64
#  11  year                67360 non-null  int64
#  12  month               67360 non-null  int64
#  13  day                 67360 non-null  int64
#  14  time                67360 non-null  object
#  15  revenue             67360 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(4), int64(4), object(5)
# memory usage: 7.7+ MB

# %% [markdown]
# # Tab 2: Items

# %%
df2=pd.read_excel(r'C:\Users\alexd\Business_Case_ADA\Data\Items_orig.xlsx')

df2.head()

## Data import
# Out:
#      ID                         Product name  item cost   price Unit sales
# 0   8.0                BEBIDA YOSOY AVENA 1L       0.94  1.2909         78
# 1  10.0             BEBIDA YOSOY SOJA NAT.1L       0.70  1.0273
# 2  32.0    TORTITA BICENTURY MAIZ QUESO 123G       1.45  2.3182         29
# 3  33.0  TORTITA BICENTURY MAIZ OLIVAS 123GR       1.45  2.3182          8
# 4  35.0   TORTITA BICENTURY MAIZ TOMATE 123G       1.45  2.3182         17

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2565 entries, 0 to 2564
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            2167 non-null   float64
#  1   Product name  2565 non-null   object
#  2   item cost     2210 non-null   float64
#  3   price         2565 non-null   float64
#  4   Unit sales    2565 non-null   object
# dtypes: float64(3), object(2)
# memory usage: 100.3+ KB

# %%
df2.columns
# Out:
# Index(['ID', 'Product name', 'item cost', 'price', 'Unit sales'], dtype='object')

# %%
df2.columns =['product_id', 'name', 'item_cost', 'price', 'unit_sales']
## Columns names are changed in order to call them easily.

# %%
df2['product_id'] = df2['product_id'].fillna(0)
df2['product_id'] = df2['product_id'].astype('int')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2565 entries, 0 to 2564
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  2565 non-null   int32
#  1   name        2565 non-null   object
#  2   item_cost   2210 non-null   float64
#  3   price       2565 non-null   float64
#  4   unit_sales  2565 non-null   object
# dtypes: float64(2), int32(1), object(2)
# memory usage: 90.3+ KB

# %%
df2 = df2.drop(df2[df2.isnull().sum(axis=1) ==1].index)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 0 to 2564
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  2210 non-null   int32
#  1   name        2210 non-null   object
#  2   item_cost   2210 non-null   float64
#  3   price       2210 non-null   float64
#  4   unit_sales  2210 non-null   object
# dtypes: float64(2), int32(1), object(2)
# memory usage: 95.0+ KB

# %%
df2.head()
# Out:
#    product_id                                 name  item_cost   price  \
# 0           8                BEBIDA YOSOY AVENA 1L       0.94  1.2909
# 1          10             BEBIDA YOSOY SOJA NAT.1L       0.70  1.0273
# 2          32    TORTITA BICENTURY MAIZ QUESO 123G       1.45  2.3182
# 3          33  TORTITA BICENTURY MAIZ OLIVAS 123GR       1.45  2.3182
# 4          35   TORTITA BICENTURY MAIZ TOMATE 123G       1.45  2.3182
#
#   unit_sales
# 0         78
# 1
# 2         29
# 3          8
# 4         17

# %%
df2['unit_sales']=df2['unit_sales'].replace(' ',0)

# %%
df2['unit_sales'] = df2['unit_sales'].astype('int')

# %%
df2.head()
# Out:
#    product_id                                 name  item_cost   price  \
# 0           8                BEBIDA YOSOY AVENA 1L       0.94  1.2909
# 1          10             BEBIDA YOSOY SOJA NAT.1L       0.70  1.0273
# 2          32    TORTITA BICENTURY MAIZ QUESO 123G       1.45  2.3182
# 3          33  TORTITA BICENTURY MAIZ OLIVAS 123GR       1.45  2.3182
# 4          35   TORTITA BICENTURY MAIZ TOMATE 123G       1.45  2.3182
#
#    unit_sales
# 0          78
# 1           0
# 2          29
# 3           8
# 4          17

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2210 entries, 0 to 2564
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  2210 non-null   int32
#  1   name        2210 non-null   object
#  2   item_cost   2210 non-null   float64
#  3   price       2210 non-null   float64
#  4   unit_sales  2210 non-null   int32
# dtypes: float64(2), int32(2), object(1)
# memory usage: 86.3+ KB

# %% [markdown]
# ### Step 4: SQL Query

# %%
# %pip install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in c:\users\alexd\downloads\descargaanaconda\lib\site-packages (1.4.22)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\alexd\downloads\descargaanaconda\lib\site-packages (from SQLAlchemy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\alexd\downloads\descargaanaconda\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
# Crear base de datos bc_glovo_ada

# lenguaje+driver://usuario:password@servidor:puerto

str_conn='mysql+pymysql://root:password@localhost:3306'

cursor=create_engine(str_conn)

cursor.execute('create database bc_glovo_ada;')

# %%
# Conexion a base de datos bc_glovo_ada

# lenguaje+driver://usuario:password@servidor:puerto/database

str_conn='mysql+pymysql://root:password@localhost:3306/bc_glovo_ada'

cursor=create_engine(str_conn)

# %%
# insercion de datos en la base de datos bc_glovo_ada

df2.to_sql(name='items', con=cursor, if_exists='replace', index=False)

# %%
# insercion de datos en la base de datos bc_glovo_ada

df.to_sql(name='customer_orders', con=cursor, if_exists='replace', index=True)

# %%
query='''
        select *
        
        from customer_orders
        
        left join items
        on customer_orders.name=items.name; '''

# %%
df_sql=pd.read_sql(query, cursor)

df_sql.head()
# Out:
#    index  product_id  external_id                          name  \
# 0      0    15301699         4687  RON CACIQUE AÑEJO 70CL 37.5º
# 1      1    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 2      2    15301814         2028               DONUTS GLACE 2U
# 3      3    18092599         3474     BARRITA CHOCO KRISPIES 6U
# 4      4    18092614         3496       CEREAL CORN FLAKES 500G
#
#                 collection_group        collection_name collection_section  \
# 0                        Bebidas      Alcohol y Licores     Top Ventas,Ron
# 1  Desayunos, Panadería y Dulces               Cereales            Barrita
# 2  Desayunos, Panadería y Dulces  Pastelería y Bollería           Bollería
# 3  Desayunos, Panadería y Dulces               Cereales            Barrita
# 4  Desayunos, Panadería y Dulces               Cereales     Para Desayunar
#
#    product_price  quantity  order_id                date  navidad  year  \
# 0          11.89         1  23899437 2018-12-28 02:17:44        0  2018
# 1           2.39         1  23892594 2018-12-28 01:01:09        0  2018
# 2           1.29         2  23901162 2018-12-28 02:40:11        0  2018
# 3           2.39         1  23907173 2018-12-28 06:00:56        0  2018
# 4           1.99         1  23900413 2018-12-28 02:29:43        0  2018
#
#    month  day       time  revenue  product_id                          name  \
# 0     12   28  Madrugada    11.89     46475.0  RON CACIQUE AÑEJO 70CL 37.5º
# 1     12   28  Madrugada     2.39     34665.0     BARRITA CHOCO KRISPIES 6U
# 2     12   28  Madrugada     2.58     22939.0               DONUTS GLACE 2U
# 3     12   28     Mañana     2.39     34665.0     BARRITA CHOCO KRISPIES 6U
# 4     12   28  Madrugada     1.99     34947.0       CEREAL CORN FLAKES 500G
#
#    item_cost   price  unit_sales
# 0       8.79  9.8300       398.0
# 1       1.59  2.1727        93.0
# 2       0.82  1.1727       425.0
# 3       1.59  2.1727        93.0
# 4       1.72  1.8091        94.0

# %%
df_sql.columns
# Out:
# Index(['index', 'product_id', 'external_id', 'name', 'collection_group',
#        'collection_name', 'collection_section', 'product_price', 'quantity',
#        'order_id', 'date', 'navidad', 'year', 'month', 'day', 'time',
#        'revenue', 'product_id', 'name', 'item_cost', 'price', 'unit_sales'],
#       dtype='object')

# %%
df_sql.columns =['index', 'product_id', 'external_id', 'name1', 'collection_group',
       'collection_name', 'collection_section', 'product_price', 'quantity',
       'order_id', 'date', 'navidad', 'year', 'month', 'day', 'time',
       'revenue', 'product_id', 'name2', 'item_cost', 'price', 'unit_sales']

## Columns names are changed in order to call them easily.

# %%
df_sql.query('name1 != name2')
# Out:
#        index  product_id  external_id name1      collection_group  \
# 62        62    18093252         3843  None  Alimentación General
# 86        97    18093232         3842  None  Alimentación General
# 182      228    18093247         8137  None               Bebidas
# 286      332    18016916        11686  None               Navidad
# 322      368    18065134         3843  None  Alimentación General
# ...      ...         ...          ...   ...                   ...
# 67222  67268    10986719         1899  None               Bebidas
# 67242  67288    10952900         3843  None  Alimentación General
# 67271  67317    10986606         2852  None               Bebidas
# 67319  67365    10986651         2284  None               Bebidas
# 67359  67405    10987018         3843  None  Alimentación General
#
#           collection_name collection_section  product_price  quantity  \
# 62     Aperitivos Salados     Patatas Fritas           1.90         1
# 86     Aperitivos Salados     Patatas Fritas           1.90         1
# 182     Alcohol y Licores            Ginebra           8.95         1
# 286             Congelado            Marisco          23.49         1
# 322    Aperitivos Salados     Patatas Fritas           1.90         1
# ...                   ...                ...            ...       ...
# 67222               Vinos             Blanco           3.79         1
# 67242  Aperitivos Salados     Patatas Fritas           1.90         1
# 67271             Cerveza       Pack y Litro           2.85         1
# 67319               Vinos              Tinto           6.59         3
# 67359  Aperitivos Salados     Patatas Fritas           1.90         1
#
#        order_id                date  navidad  year  month  day       time  \
# 62     23890319 2018-12-28 00:34:26        0  2018     12   28  Madrugada
# 86     23895886 2018-12-28 01:36:41        0  2018     12   28  Madrugada
# 182    23891907 2018-12-28 00:53:31        0  2018     12   28  Madrugada
# 286    23830139 2018-12-27 16:03:54        1  2018     12   27      Tarde
# 322    23837189 2018-12-27 17:25:54        0  2018     12   27      Tarde
# ...         ...                 ...      ...   ...    ...  ...        ...
# 67222  15973199 2018-10-16 23:05:19        0  2018     10   16      Noche
# 67242  15924126 2018-10-16 13:41:39        0  2018     10   16      Tarde
# 67271  15965044 2018-10-16 21:48:57        0  2018     10   16      Noche
# 67319  15968770 2018-10-16 22:20:23        0  2018     10   16      Noche
# 67359  15968106 2018-10-16 22:13:41        0  2018     10   16      Noche
#
#        revenue  product_id name2  item_cost  price  unit_sales
# 62        1.90         NaN  None        NaN    NaN         NaN
# 86        1.90         NaN  None        NaN    NaN         NaN
# 182       8.95         NaN  None        NaN    NaN         NaN
# 286      23.49         NaN  None        NaN    NaN         NaN
# 322       1.90         NaN  None        NaN    NaN         NaN
# ...        ...         ...   ...        ...    ...         ...
# 67222     3.79         NaN  None        NaN    NaN         NaN
# 67242     1.90         NaN  None        NaN    NaN         NaN
# 67271     2.85         NaN  None        NaN    NaN         NaN
# 67319    19.77         NaN  None        NaN    NaN         NaN
# 67359     1.90         NaN  None        NaN    NaN         NaN
#
# [1847 rows x 22 columns]

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67360 entries, 0 to 67359
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               67360 non-null  int64
#  1   product_id          67360 non-null  int64
#  2   external_id         67360 non-null  int64
#  3   name1               65513 non-null  object
#  4   collection_group    67360 non-null  object
#  5   collection_name     67360 non-null  object
#  6   collection_section  67360 non-null  object
#  7   product_price       67360 non-null  float64
#  8   quantity            67360 non-null  int64
#  9   order_id            67360 non-null  int64
#  10  date                67360 non-null  datetime64[ns]
#  11  navidad             67360 non-null  int64
#  12  year                67360 non-null  int64
#  13  month               67360 non-null  int64
#  14  day                 67360 non-null  int64
#  15  time                67360 non-null  object
#  16  revenue             67360 non-null  float64
#  17  product_id          65513 non-null  float64
#  18  name2               65513 non-null  object
#  19  item_cost           65513 non-null  float64
#  20  price               65513 non-null  float64
#  21  unit_sales          65513 non-null  float64
# dtypes: datetime64[ns](1), float64(6), int64(9), object(6)
# memory usage: 11.3+ MB
